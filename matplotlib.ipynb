# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
# %matplotlib inline

# %%
x = np.linspace(0, 10, 100)
y = np.linspace(0, 10, 100)
fig = plt.figure()
plt.plot(x, np.sin(x), '-')
plt.plot(y, np.cos(x), '--');

# %%
fig, ax = plt.subplots(2)
ax[0].plot(x, np.sin(x))
ax[1].plot(x, np.cos(x));

# %%
plt.style.use('seaborn-whitegrid')
fig = plt.figure()
ax = plt.axes()

# %%
fig = plt.figure()
ax = plt.axes()
x = np.linspace(0, 20, 1000)
ax.plot(x, np.sin(x));

# %%
plt.plot(x, np.sin(x));

# %%
plt.plot(x, np.sin(x))
plt.plot(x, np.cos(x));

# %%
plt.plot(x, np.sin(x - 0), color='blue') ;

# %%
plt.plot(x, np.sin(x - 1), color='g') ;

# %%
plt.plot(x, np.sin(x - 2), color='0.75');

# %%
plt.plot(x, np.sin(x - 3), color='#FFDD44');

# %%
plt.plot(x, np.sin(x - 4), color=(1.0,0.2,0.3));

# %%
plt.plot(x, np.sin(x - 5), color='chartreuse');

# %%
x=np.linspace(0,10,100)
plt.plot(x, x + 0, linestyle='solid')
plt.plot(x, x + 1, linestyle='dashed')
plt.plot(x, x + 2, linestyle='dashdot')
plt.plot(x, x + 3, linestyle='dotted');

# %%
plt.plot(x, x + 4, linestyle='-') 
plt.plot(x, x + 5, linestyle='--')
plt.plot(x, x + 6, linestyle='-.')
plt.plot(x, x + 7, linestyle=':');

# %%
plt.plot(x, x + 0, '-g') 
plt.plot(x, x + 1, '--c') 
plt.plot(x, x + 2, '-.k') 
plt.plot(x, x + 3, ':r');

# %%
plt.plot(x, np.sin(x))
plt.xlim(-1, 11)
plt.ylim(-2,2);

# %%
plt.plot(x, np.sin(x))
plt.xlim(11, -1)
plt.ylim(2, -2);

# %%
plt.plot(x, np.sin(x))
plt.axis([-1, 11, -3, 3]);

# %%
plt.plot(x, np.sin(x))
plt.axis('tight');

# %%
plt.plot(x, np.sin(x))
plt.axis('equal');
plt.title("A Sine Curve");
plt.xlabel("x")
plt.ylabel("sin(x)");

# %%
plt.plot(x, np.sin(x), '-g', label='sin(x)')
plt.plot(x, np.cos(x), ':b', label='cos(x)')
plt.axis('equal')
plt.legend();

# %%
ax = plt.axes()
ax.plot(x, np.sin(x))
ax.set(xlim=(0, 10), ylim=(-2, 2),xlabel='x', ylabel='sin(x)',title='A Simple Plot');

# %%
plt.style.use('seaborn-whitegrid')
x = np.linspace(0, 10, 30)
plt.plot(x, np.sin(x), '*b');

# %%
rng = np.random.RandomState(0)
for i in ['o', '.', ',', 'x', '+', 'v', '^', '<', '>', 's', 'd']:
 plt.plot(rng.rand(5), rng.rand(5), i,
 label="i".format(i))
plt.legend(numpoints=1)
plt.xlim(0, 1.8);

# %%
plt.plot(x, np.sin(x), '-ok');

# %%
plt.plot(x, np.sin(x), '-p', color='gray', markersize=10, linewidth=4,
         markerfacecolor='white', markeredgecolor='gray',markeredgewidth=2)
plt.ylim(-1.2, 1.2);

# %%
plt.scatter(x, np.sin(x), marker='o');

# %%
rng = np.random.RandomState(0)
x = rng.randn(100)
y = rng.randn(100)
colors = rng.rand(100)
sizes = 1000 * rng.rand(100)
plt.scatter(x, y, c=colors, s=sizes, alpha=0.3,cmap='viridis')
plt.colorbar();

# %%
from sklearn.datasets import load_iris
iris = load_iris()
features = iris.data.T
plt.scatter(features[0], features[1], alpha=0.3, s=100*features[1], c=iris.target, cmap='viridis')
plt.xlabel(iris.feature_names[0])
plt.ylabel(iris.feature_names[1]);
plt.colorbar();
