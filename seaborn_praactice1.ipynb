# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
df=pd.read_csv('CAR DETAILS FROM CAR DEKHO.csv')

# %%
df.head()
# Out:
#                        name  year  selling_price  km_driven    fuel  \
# 0             Maruti 800 AC  2007          60000      70000  Petrol
# 1  Maruti Wagon R LXI Minor  2007         135000      50000  Petrol
# 2      Hyundai Verna 1.6 SX  2012         600000     100000  Diesel
# 3    Datsun RediGO T Option  2017         250000      46000  Petrol
# 4     Honda Amaze VX i-DTEC  2014         450000     141000  Diesel
#
#   seller_type transmission         owner
# 0  Individual       Manual   First Owner
# 1  Individual       Manual   First Owner
# 2  Individual       Manual   First Owner
# 3  Individual       Manual   First Owner
# 4  Individual       Manual  Second Owner

# %%
df.shape
# Out:
# (4340, 8)

# %%
df['Age']=2021- df['year']
df.head(5)
# Out:
#                        name  year  selling_price  km_driven    fuel  \
# 0             Maruti 800 AC  2007          60000      70000  Petrol
# 1  Maruti Wagon R LXI Minor  2007         135000      50000  Petrol
# 2      Hyundai Verna 1.6 SX  2012         600000     100000  Diesel
# 3    Datsun RediGO T Option  2017         250000      46000  Petrol
# 4     Honda Amaze VX i-DTEC  2014         450000     141000  Diesel
#
#   seller_type transmission         owner  Age
# 0  Individual       Manual   First Owner   14
# 1  Individual       Manual   First Owner   14
# 2  Individual       Manual   First Owner    9
# 3  Individual       Manual   First Owner    4
# 4  Individual       Manual  Second Owner    7

# %%
del (df['year'])

# %%
df
# Out:
#                                      name  selling_price  km_driven    fuel  \
# 0                           Maruti 800 AC          60000      70000  Petrol
# 1                Maruti Wagon R LXI Minor         135000      50000  Petrol
# 2                    Hyundai Verna 1.6 SX         600000     100000  Diesel
# 3                  Datsun RediGO T Option         250000      46000  Petrol
# 4                   Honda Amaze VX i-DTEC         450000     141000  Diesel
# ...                                   ...            ...        ...     ...
# 4335  Hyundai i20 Magna 1.4 CRDi (Diesel)         409999      80000  Diesel
# 4336           Hyundai i20 Magna 1.4 CRDi         409999      80000  Diesel
# 4337                  Maruti 800 AC BSIII         110000      83000  Petrol
# 4338     Hyundai Creta 1.6 CRDi SX Option         865000      90000  Diesel
# 4339                     Renault KWID RXT         225000      40000  Petrol
#
#      seller_type transmission         owner  Age
# ...

# %%
sns.set_color_codes()
sns.distplot(df['Age'],rug=True,kde=False,color='g')
# Out:
# C:\Users\Tandale Datta\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\Tandale Datta\anaconda3\lib\site-packages\seaborn\distributions.py:2055: FutureWarning: The `axis` variable is no longer used and will be removed. Instead, assign variables directly to `x` or `y`.
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Age'>

# %% [markdown]
# maximum of cars are  betwin 1 to 15 year old
# also there are some cars that 15 to 30 year old

# %%
sns.pairplot(df)

# %% [markdown]
# selling price depend on how many kilometer driven
#
# some cars are old but driven less and some cars age avarage but they travel long
#
# maximum cars driven less than 250.000 kilometer but there are outlier

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4340 entries, 0 to 4339
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   name           4340 non-null   object
#  1   selling_price  4340 non-null   int64
#  2   km_driven      4340 non-null   int64
#  3   fuel           4340 non-null   object
#  4   seller_type    4340 non-null   object
#  5   transmission   4340 non-null   object
#  6   owner          4340 non-null   object
#  7   Age            4340 non-null   int64
# dtypes: int64(3), object(5)
# memory usage: 271.4+ KB

# %%
sns.catplot(y='selling_price',x='fuel',data=df)

# %% [markdown]
# diesel cars more high valued than other
#
# petrol are scond best option but most expancive car is use petrol
#
# lpg and cng cars are  less valued
#
# electric =1

# %%
sns.catplot(y='km_driven',x='fuel',kind='boxen',data=df)

# %% [markdown]
# diesel cars driven ost are and own by many
#
# petrol cars 2 best driven but has one highest driven car
#
# Lpg cars are more driven than Cng

# %%
sns.catplot(y='transmission',x='fuel',data=df)

# %% [markdown]
# Lpg and Cng don't have automatic transmission
#
# electric car don't have manual transmission

# %%
df['name'].mode()
# Out:
# 0    Maruti Swift Dzire VDI
# dtype: object

# %% [markdown]
# Maruti Swift Dzire VDI is most common car

# %%
df['selling_price'].mean()
# Out:
# 504127.3117511521

# %% [markdown]
# avarage value of cars is near to 505269rs

# %%
sns.jointplot(x='owner',y='selling_price',data=df)

# %% [markdown]
# first  owner cars have highest selling price

# %%
print(df['name'].value_counts())
# Out:
# Maruti Swift Dzire VDI                            69
# Maruti Alto 800 LXI                               59
# Maruti Alto LXi                                   47
# Maruti Alto LX                                    35
# Hyundai EON Era Plus                              35
#                                                   ..
# Maruti Celerio ZXI MT BSIV                         1
# Ford Ecosport 1.5 DV5 MT Trend                     1
# Ford EcoSport 1.5 Petrol Titanium Plus AT BSIV     1
# Hyundai Verna Transform CRDi VGT SX ABS            1
# Jaguar XJ 5.0 L V8 Supercharged                    1
# Name: name, Length: 1491, dtype: int64

# %% [raw]
# maruti brands cars are most common

# %%
print(df['fuel'].value_counts())
# Out:
# Diesel      2153
# Petrol      2123
# CNG           40
# LPG           23
# Electric       1
# Name: fuel, dtype: int64

# %% [markdown]
# there are equal ammount of car of diesel and petrol

# %%
sns.relplot(x='selling_price',y= 'km_driven',col='fuel',data=df)

# %%
sns.relplot(x='selling_price',y= 'km_driven',hue='fuel',data=df)

# %%
sns.lineplot(x='selling_price',y= 'km_driven',data=df)
# Out:
# <AxesSubplot:xlabel='selling_price', ylabel='km_driven'>

# %%
sns.scatterplot(x='km_driven',y='Age',data=df)
# Out:
# <AxesSubplot:xlabel='km_driven', ylabel='Age'>

# %%
sns.lineplot(x='Age',y='selling_price',data=df)
# Out:
# <AxesSubplot:xlabel='Age', ylabel='selling_price'>

# %%
sns.boxplot(y='fuel',x='Age',data=df)
# Out:
# <AxesSubplot:xlabel='Age', ylabel='fuel'>

# %%
sns.stripplot(y='fuel',x='Age',data=df)
# Out:
# <AxesSubplot:xlabel='Age', ylabel='fuel'>

# %%
sns.swarmplot(y='fuel',x='Age',data=df)
# Out:
# C:\Users\Tandale Datta\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 92.2% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\Tandale Datta\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 93.6% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# <AxesSubplot:xlabel='Age', ylabel='fuel'>

# %%
sns.kdeplot(df['km_driven'])
# Out:
# <AxesSubplot:xlabel='km_driven', ylabel='Density'>

# %%
sns.jointplot(x=df['Age'],y=df['km_driven'])

# %%
sns.rugplot(y=df['Age'])
# Out:
# <AxesSubplot:ylabel='Age'>

# %%
sns.regplot(x=df['Age'],y=df['km_driven'])
# Out:
# <AxesSubplot:xlabel='Age', ylabel='km_driven'>

# %%
df.head(2)
# Out:
#                        name  selling_price  km_driven    fuel seller_type  \
# 0             Maruti 800 AC          60000      70000  Petrol  Individual
# 1  Maruti Wagon R LXI Minor         135000      50000  Petrol  Individual
#
#   transmission        owner  Age
# 0       Manual  First Owner   14
# 1       Manual  First Owner   14
